# %% [markdown]
# # Comparação - Embeddings

# %%
import pandas as pd

# %%
embeddings = pd.read_csv("embeddings.csv")

# %%
embeddings
# Out:
#                                        name        model  cosine_similarity
# 0    2025_ufc_inova_1_simplificado_stripped  phi3-latest           0.911089
# 1                 2025_ufc_inova_1_stripped  phi3-latest           0.872263
# 2                 2025_ufc_inova_2_stripped  phi3-latest           0.796808
# 3                 2025_ufc_inova_3_stripped  phi3-latest           0.786570
# 4                 2025_ufc_inova_4_stripped  phi3-latest           0.771557
# ..                                      ...          ...                ...
# 105  2025_ufc_inova_5_simplificado_stripped  phi4-latest           0.994724
# 106               2025_ufc_inova_5_stripped  phi4-latest           0.988550
# 107  2025_ufc_inova_6_simplificado_stripped  phi4-latest           0.994919
# 108               2025_ufc_inova_7_stripped  phi4-latest           0.985826
# 109               2025_ufc_inova_8_stripped  phi4-latest           0.993372
#
# [110 rows x 3 columns]

# %%
embeddings["cosine_similarity"].min(),embeddings["cosine_similarity"].max()
# Out:
# (np.float64(0.714305579662323), np.float64(0.998994529247284))

# %%
embeddings.groupby("model").agg({"recall": "mean","precision":"mean","f1_score":"mean"})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 embeddings.groupby("model").agg({"recall": "mean","precision":"mean","f1_score":"mean"})
#
# NameError: name 'embeddings' is not defined
